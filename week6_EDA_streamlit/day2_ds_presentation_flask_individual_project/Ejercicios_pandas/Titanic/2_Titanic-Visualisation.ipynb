# %% [markdown]
#    #                                                  Titanic Exercise II
#    #### Practice matplotlib & seaborn

# %% [markdown]
# ![titanic](https://userscontent2.emaze.com/images/a5f68f37-6349-4065-a1fc-921cbe7401b2/958230111417e36d6b3c67ffd7bc3494.jpeg)

# %% [markdown]
# First of all, import the needed libraries.

# %%
import pandas as pd
import numpy as np
import os 
import random
import matplotlib.pyplot as plt
import seaborn as sns

# visualisation libraries

# %% [markdown]
# 1. Read the `.csv` file you generated in **1_Titanic-Pandas** `titanic_cleaned.csv` and call the variable `titanic`.
#
# Help: If you didn't get to the point in which you should have saved the file, ask the instructor.

# %%
filename = "titanic_cleaned.csv"

# %%
os.chdir("C:\\Users\\Administrator\\Desktop\\TheBridge\\Bootcamp-DataScience-2021\\week6_EDA_streamlit\\day2_ds_presentation_flask_individual_project\\Ejercicios_pandas\\Titanic\\data")

# %%
#your code
titanic=pd.read_csv("titanic_cleaned.csv")
titanic
# Out:
#       Unnamed: 0  pclass  survived  \
# 0              0       1         1
# 1              1       1         1
# 2              2       1         0
# 3              3       1         0
# 4              4       1         0
# ...          ...     ...       ...
# 1304        1304       3         0
# 1305        1305       3         0
# 1306        1306       3         0
# 1307        1307       3         0
# 1308        1308       3         0
#
#                                                  name     sex    age  sibsp  \
# 0                       Allen, Miss. Elisabeth Walton  female  29.00      0
# 1                      Allison, Master. Hudson Trevor    male   0.92      1
# 2                        Allison, Miss. Helen Loraine  female   2.00      1
# 3                Allison, Mr. Hudson Joshua Creighton    male  30.00      1
# 4     Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female  25.00      1
# ...                                               ...     ...    ...    ...
# 1304                             Zabour, Miss. Hileni  female  14.50      1
# 1305                            Zabour, Miss. Thamine  female    NaN      1
# 1306                        Zakarian, Mr. Mapriededer    male  26.50      0
# 1307                              Zakarian, Mr. Ortin    male  27.00      0
# 1308                               Zimmerman, Mr. Leo    male  29.00      0
#
#       parch  ticket      fare    cabin embarked boat   body  \
# 0         0   24160  211.3375       B5        S    2    NaN
# 1         2  113781  151.5500  C22 C26        S   11    NaN
# 2         2  113781  151.5500  C22 C26        S  NaN    NaN
# 3         2  113781  151.5500  C22 C26        S  NaN  135.0
# 4         2  113781  151.5500  C22 C26        S  NaN    NaN
# ...     ...     ...       ...      ...      ...  ...    ...
# 1304      0    2665   14.4542      NaN        C  NaN  328.0
# 1305      0    2665   14.4542      NaN        C  NaN    NaN
# 1306      0    2656    7.2250      NaN        C  NaN  304.0
# 1307      0    2670    7.2250      NaN        C  NaN    NaN
# 1308      0  315082    7.8750      NaN        S  NaN    NaN
#
#                             home.dest  gender
# 0                        St Louis, MO    True
# 1     Montreal, PQ / Chesterville, ON   False
# 2     Montreal, PQ / Chesterville, ON    True
# 3     Montreal, PQ / Chesterville, ON   False
# 4     Montreal, PQ / Chesterville, ON    True
# ...                               ...     ...
# 1304                              NaN    True
# 1305                              NaN    True
# 1306                              NaN   False
# 1307                              NaN   False
# 1308                              NaN   False
#
# [1309 rows x 16 columns]

# %% [markdown]
# 2. Using matplotlib find the appropriate visualization to show the distribution of the column `age`

# %%
#your code here

plt.hist(titanic["age"])
# Out:
# (array([ 72.,  62., 274., 250., 161., 108.,  65.,  41.,  10.,   3.]),
#  array([ 0.17 ,  8.153, 16.136, 24.119, 32.102, 40.085, 48.068, 56.051,
#         64.034, 72.017, 80.   ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# 3. Now use seaborn to show the distribution of the column `age`.

# %%
#your code here

sns.displot(titanic["age"], x=titanic["age"])

# %% [markdown]
# 4. Use subplots to plot the distribution of the Age variable with bins equal to 10, 20 and 50.
#
# Use `sns.histplot()` for that aim.

# %%
#your code here
sns.histplot(titanic["age"],x=titanic["age"],bins=10)
# Out:
# <AxesSubplot:xlabel='age', ylabel='Count'>

# %%
sns.histplot(titanic["age"],x=titanic["age"],bins=20)
# Out:
# <AxesSubplot:xlabel='age', ylabel='Count'>

# %%
sns.histplot(titanic["age"],x=titanic["age"],bins=50)
# Out:
# <AxesSubplot:xlabel='age', ylabel='Count'>

# %% [markdown]
# 5. Whether the bin size affects your plot? Why?

# %%
#your comment here
#separa más los datos de la grafica como que lo divide en grupos más pequeños

# %% [markdown]
# 6. Using matplotlib find the appropriate plot to visualize the column `'gender'`

# %%
# your code here

plt.bar(titanic["sex"])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-23-140c502ae26e> in <module>
#       1 # your code here
#       2
# ----> 3 plt.bar(titanic["sex"])
#
# TypeError: bar() missing 1 required positional argument: 'height'

# %% [markdown]
# 7. What if you also plot the column `'gender'` using the function [`countplot`](https://seaborn.pydata.org/generated/seaborn.countplot.html) from the library [`seaborn`](https://seaborn.pydata.org/)?

# %%
#your code
sns.countplot(titanic["sex"],x=titanic["sex"])
# Out:
# C:\Users\Administrator\AppData\Local\Programs\Python\Python37\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# <AxesSubplot:xlabel='sex', ylabel='count'>

# %% [markdown]
# 6. Using the function [`catplot`](https://seaborn.pydata.org/generated/seaborn.catplot.html) from the library `seaborn`, find out if the hypothesis _"Women are more likely to survive shipwrecks"_ is true or not.
#
# You should get something like this:

# %%
sns.catplot(x="sex", y="survived", kind="bar", data=titanic)

# %% [markdown]
# 7. Use the appropriate plot to visualize the column `pclass`.

# %%
#your code
sns.catplot(y="pclass", hue="pclass", kind="count", data=titanic)

# %% [markdown]
# 8. We would like to have in one single plot the summary statistics of the feature `age`. Choose the appropriate plot to show below.

# %%
#your code
age_labels = ["0-9","10-19", "20-29", "30-39", "40-49", "50-59", "60-69", "70-79"]
titanic["age_group"] = pd.cut(titanic["age"], range(0, 81, 10), labels=age_labels)

titanic.groupby(["age_group"]).size().plot(kind="bar")
# Out:
# <AxesSubplot:xlabel='age_group'>

# %% [markdown]
# 9. What does the previous plot tell you about the feature Age? Comment.

# %%
# your comment here
#most of the people were young-mid age people

# %% [markdown]
# 10. Now in addition to the summary statistics, we also want to visualize the distribution of `age`. Choose the appropriate plot to show below.

# %%
#your code 

sns.displot(data=titanic, x="age", stat="density")

# %% [markdown]
# 11. Use the appropriate plot to display the distributions of `age` in relation to `gender`.
#
# Hint: use Facetgrid to display the distribution of age for each categorical value of gender.

# %%
#your code
sns.displot(data=titanic, x="age", hue="sex", stat="density")

# %% [markdown]
# 12. Using [`kdeplot`]("https://seaborn.pydata.org/generated/seaborn.kdeplot.html") from `seaborn` represent those who not survived distributed by age.
#
# Hint: First you should "filter" the `titanic` dataset where the column "survived" is 0, indexing the column `"age"` only.
#
# Arguments you should pass to the function:
#
#     - color = "red"
#     - label = "Not Survived"
#     - shade = True
#
# You should get something like this:

# %%
sns.kdeplot(data=titanic ,x="age", hue="survived",color="red",shade=True)
# Out:
# <AxesSubplot:xlabel='age', ylabel='Density'>

# %% [markdown]
# ![kdeplot](img/kdeplot.png)

# %%
#your code

# %% [markdown]
# 13. Using Seaborn plot the correlation matrix of various features.
#
# Hint: search how to use `heatmap`

# %%
#your code here
plt.figure(figsize=(10,10))
sns.heatmap(titanic.corr(),square=True,linewidths=.3,cmap=sns.cm.rocket_r)
# Out:
# <AxesSubplot:>

# %% [markdown]
# 14. According to the previous plot, what are the most correlated feature? Comment.

# %%
#your comment here
# survived with gender the least correlated are body and survived
